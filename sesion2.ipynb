# %% [markdown]
# # EDINSON JOEL BOTELLO PROGRAMA MISION TIC 2022 CICLO 1 FUNDAMENTOS DE PROGRAMACION EJERCICIOS SESION 2

# %% [markdown]
# # Fundamentos de Programación con Python
#
# ## Estructuras algorítmicas
#
# Vamos a trabajar en modificar el algoritmo y pasarlo a Python.
#
# Inicio
#
#     a ⇐ 2
#     b ⇐ 3
#     c ⇐ 1
#     x1 ⇐ (-b + ((b^2)-(4*a*c))^(½))/(2*a)
#     x2 ⇐ (-b - ((b^2)-(4*a*c))^(½))/(2*a)
#     escribir x1
#     escribir x2
# Fin
#
#
# Además de las operaciones matemáticas básicas que vimos en la sesión anterior, también podemos importar otras operaciones o funciones desde una "librería" (aunque la traducción correcta de library es biblioteca, en español se ha vuelto más común hablar de librerías).
#
# Por ejemplo, podemos usar la función raíz cuadrada sqrt importando math. Escribe el código para imprimir la raíz cuadrada de un valor.

# %%
import math
#math.sqrt(x)

# %% [markdown]
# Puedes ver todas las funciones que tiene esta librería y cómo se usan, con los siguientes comandos:

# %%
#dir(math)           # Lista de funciones
help(math)          # Ayuda sobre la librería math

#help(math.sqrt)     # Ayuda sobre la función sqrt

# %% [markdown]
# Volvamos al algoritmo entonces. En la prueba de escritorio, determinamos que (b^2)-(4*a*c) debe ser mayor a 0 para poder obtener la raiz cuadrada. Aquí vamos a modificar los valores para ejecutar el código. Mas adelante, con condicionales podremos evaluar los valores durante la ejecución e imprimir un mensaje en caso de error.

# %%
import math
a = 2 
b = 3
c = 1
x1 = (-b + math.sqrt((b**2)-(4*a*c)))/(2*a)
x2 = (-b - math.sqrt((b**2)-(4*a*c)))/(2*a)
print(x1)
print(x2)

# %%
c = 2.0

d = 2.0

print(id(c),id(d),id(2.0))

print('c == d:',c==d)

print('c is d:',c is d)
# Out:
# 1548845205712 1548845206576 1548845204304
# c == d: True
# c is d: False

# %% [markdown]
# ### Actividad 1
#
# Los tipos de datos son muy importantes en programación. Aunque Python no exige declarar un tipo de variable y permite cambiarlo (lo cual no ocurre en otros lenguajes de programación), cada variable si asume un tipo según el dato que tenga almacenado. Por ejemplo:

# %%
a = 5     # Esto es un Entero (No tiene decimales)
b = 5.3   # Esto es un flotante (Un número que puede tener comas decimals)
c = '5'   # Esto es un texto, y por ende, no podemos hacer operaciones matemáticas con c

# %% [markdown]
# Usando la función type(), obten e imprime el tipo de dato de las variables a, b y c:

# %% [markdown]
# ### Actividad 2
#
# Ahora, practiquemos nuevamente la estructura algorítmica y recordemos el uso de tipos de datos.
#
# Juan y Pedro acostumbran jugar un juego de adivinar un número. En el juego es permitido dar tres pistas p1 p2 p3. Después de muchos intentos Pedro descubre la fórmula con la que Juan crea el número con las pistas dadas, y es la siguiente:
#
#     p1 + p3 ∗ p2 − (p1 + p2 ∗ 5 + 1) / (p2 + p1/2) + p3
#
# Si la pista que da Juan es 2, 1 y 4, ¿cuál es el número que debería decir Pedro para ganar? Escribamos el código para recibir los valores y devolver el valor que Pedro debería decir.

# %%
p1=2
p2=1
p3=4
p4=p1+p3*p2-(p1+p2*5+1)/(p2 + p1/2)+p3
print(p4)
# Out:
# 6.0

# %% [markdown]
# ## Ejercicio 3
#
# Diseñar un programa que lea el peso de un hombre en libras y nos devuelva su peso en kilogramos y gramos (Nota: una libra equivale a 0.453592 kilogramos)

# %%
wlb = float(input("Ingrese su peso en libras"))
LIBRA = 0.453592
wkg = wlb * LIBRA
wg = wkg * 1000
#print(f"el peso {wlb} en libras equivale a {wkg} kilogramos y en gramos seria de {wg}")
print ("la equivalencia del peso en libras de " + str(wlb) + " equivale en kg a: " + str(wkg) + " o en gramos seria igual a " + str(wg) )
# Out:
# la equivalencia del peso en libras de 20.0 equivale en kg a: 9.07184 o en gramos seria igual a 9071.84

# %% [markdown]
# ## Ejercicio 4
#
# Se tienen tres variables a, b y c. Escribir las instrucciones necesarias para intercambiar entre sí sus valores del modo siguiente:
#
# B toma el valor de A
#
# C toma el valor de B
#
# A toma el valor de C
#
# Nota: Utilizar una variable auxiliar que llamaremos AUX.

# %%
a=float(input("Digite el valor de a"))
b=float(input("Digite el valor de b"))
c=float(input("Digite el valor de c"))
print(f"a es igual a {a}, b es igual a {b}, c es igual a {c}")

'''Opcion 1
AUX=b
b=a
a=c
c=AUX'''

## opcion 2 volteandolo de arriba hacia abajo
aux =a
a=c
c=b
b=aux

print(f"b tomo el valor de a que es {b}, c tomo el valor de b que es {c} y a tomo el valor de c que es {a} ")
# Out:
# a es igual a 5.0, b es igual a 6.0, c es igual a 7.0
# b tomo el valor de a que es 5.0, c tomo el valor de b que es 6.0 y a tomo el valor de c que es 7.0

# %% [markdown]
# ## Ejercicio 5
# Para un empleado, lea el valor de la hora extra diurna, el número de horas extras diurnas y nocturnas trabajadas. Calcule cuánto ganó por horas extras, teniendo en cuenta que las horas nocturnas se pagan al doble.

# %%
val_hor_ed=float(input("Digite el valor de la hora diurna"))
q_hor_d=float(input("Digite la cantidad de horas extras diurnas laboradas"))
q_hor_n=float(input("Digite la cantidad de horas nocturnas laboradas"))

gano_hor_extras=(val_hor_ed*q_hor_d)+((val_hor_ed*2)*q_hor_n)
print(f"El calculo de lo que gano por horas extras diurnas y nocturnas es de {gano_hor_extras}")
# Out:
# El calculo de lo que gano por horas extras diurnas y nocturnas es de 6000.0

# %% [markdown]
# ## Ejercicio tarea 1
# Ingresar un tiempo en segundos y separarlos en horas, minutos y segundos

# %%
tseg=float(input("Ingrese el tiempo en segundos"))

''' Para que lo muestre por separado
thoras=tseg/3600
tminutos=tseg/60'''

#corriendolo con math.modf
import math
hora=tseg/3600
hora_dec, hora_ent = math.modf(hora)
min_float= hora_dec*60
min_dec, min_ent = math.modf(min_float)
seg = min_dec*60
print(f"{tseg} segundos equivalen en {int(hora_ent)} horas, {int(min_ent)} minutos y {seg} segundos")
#si uso 3661 segundos me roba 1 segundo
# Out:
# 3663.0 segundos equivalen en 1 horas, 1 minutos y 4 segundos

# %%
# realizandolo con mod y //
seg=float(input("Digite el tiempo en segundos para convertir"))

hora= seg//3600 #traemos el resultado de la parte entera
segh= seg%3600 #creamos una nueva variable que almacenara los segundos nuevos, es decir los segundos quitando los segundos que tomo la hora; que seran el residuo de dividir  los segundos entre los segundos que tiene una hora
min= segh//60
seghm= segh%60 #creamos una nueva variable que almacenara los segundos nuevos, quitandole los segundos que se llevaron las horas y minutos; este sera el residuo de la division de los segundos sin horas entre la cantidad de segundos que tiene un minuto
print(f"{seg} segundos equivalen en {hora} horas, {min} minutos y {seghm} segundos")
# Out:
# 2230000.0 segundos equivalen en 619.0 horas, 26.0 minutos y 40.0 segundos

# %% [markdown]
# ## Ejercicio tarea 2
# Leer un número por teclado y mostrar por consola, el carácter al que pertenece en la tabla ASCII. Por ejemplo: si se introduce un 97, me muestre una “a”.https://ascii.cl/es/

# %%
#Debemos pedir y almacenar el numero entero
num=int(input("Digite el numero"))
#Ahora transformamos esta variable entera en una variable tipo caracter que es la que reconoce el sistema ASCII 
letraascii=chr(num)
print(f"El Numero {num} representa dentro del sistema ASCII al caracter {letraascii}")
# Out:
# El Numero 97 representa dentro del sistema ASCII al caracter a

# %%
print(type("hola que mas"))
# Out:
# <class 'str'>
